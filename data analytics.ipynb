# %%
x = 22

print(x)
type(x)
# Out:
# 22
# int

# %%
y = 'mint choco chip'
print(y)
type(y)
# Out:
# mint choco chip
# str

# %%
x,y,z = 'chocolate','vannila', 'mango'
print(x)
print(y)
print(z)
# Out:
# chocolate
# vannila
# mango

# %%
x=y=z = "mint chips"
print(x)
# Out:
# mint chips

# %%
ice_cream = ['chocolate','vannila', 'mango']
x,y,z = ice_cream
print(x)
print(y)
print(z)
# Out:
# chocolate
# vannila
# mango

# %%
# camel case
# test variable case
testVariableCase = 'vanilla swirl'

# %%
#pascal case
# test variable case
TestVariableCase = 'vanilla swirl'

# %%
# Snake case
# test variable case
test_Variable_Case = 'vanilla swirl'

testvar = 'vanilla swirl'
test_var = 'vanilla swirl'
_test_var = 'vanilla swirl'
Testvar =  'vanilla swirl'
testvar2 = 'vanilla swirl'

# cant type 
2testvar = 'vanilla swirl'
test-var2 = 'vanilla swirl'
test var2 = 'vanilla swirl'
test,var2 =  'vanilla swirl'

# %%
x = 'ice cream is my favourite' + 2
print (x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 x = 'ice cream is my favourite' + 2
#       2 print (x)
#
# TypeError: can only concatenate str (not "int") to str

# %%
y = 3+2
print(y)

x = 'ice cream'
y = ' is'
z = ' my favourite'
print(x+y+z)
# Out:
# 5
# ice cream is my favourite

# %%
x = 'ice cream'
y = 2
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 x = 'ice cream'
#       2 y = 2
# ----> 3 print(x+y)
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = 'ice cream'
y = 2
print(x,y)
# Out:
# ice cream 2

# %%
type (-12 + 100)
# Out:
# int

# %%
type (-12 + 10.25)
# Out:
# float

# %%
type (-12 + 3j)
# Out:
# complex

# %%
#boolean
type (1>5)

1>5
# Out:
# False

# %%
#strings
'single Quote'

"double quote"
# Out:
# 'double quote'

# %%
multiline = """
the ice cream is vaniquished
my longing for sweets,
it no longer exists on this day
"""

# %%
print(multiline)
# Out:
# the ice cream is vaniquished
# my longing for sweets,
# it no longer exists on this day

# %%
"i've always wanted to eat a gallon of ice cream"
# Out:
# "i've always wanted to eat a gallon of ice cream"

# %%
a = 'hello world!'
print(a[:5])
# Out:
# hello

# %%
a*3
# Out:
# 'hello world!hello world!hello world!'

# %%
a+a
# Out:
# 'hello world!hello world!'

# %%
#list
a = [1,2,3]
print(a)
b = ['cookie dough','strawberry','chocolate']
print(b)
c = ['vanilla',3, ['scoops', 'spoon']]
print(c)
# Out:
# [1, 2, 3]
# ['cookie dough', 'strawberry', 'chocolate']
# ['vanilla', 3, ['scoops', 'spoon']]

# %%
ice_cream = ['cookie dough','strawberry','chocolate']
ice_cream.append('salted Caramel')
ice_cream
# Out:
# ['cookie dough', 'strawberry', 'chocolate', 'salted Caramel']

# %%
ice_cream[0] = 'butter pecon'
ice_cream
# Out:
# ['butter pecon', 'strawberry', 'chocolate', 'salted Caramel']

# %%
nes_list = ['vanilla',3, ['scoops', 'spoon']]
nes_list[2][1]
# Out:
# 'spoon'

# %%
#tuple
tuple_scoops = (1,2,3,2,1)
type(tuple_scoops)
# Out:
# tuple

# %%
tuple_scoops[0]
# Out:
# 1

# %%
tuple_scoops.append(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 tuple_scoops.append(3)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#set

daily_pints = {1,2,3}
type(daily_pints)
# Out:
# set

# %%
print(daily_pints)
# Out:
# {1, 2, 3}

# %%
daily_pints_log = {1,2,31,2,3,4,1,2,5,6,3,2}
print(daily_pints_log)
# Out:
# {1, 2, 3, 4, 5, 6, 31}

# %%
wifes_pints_log = {1,3,5,7,3,24,5,7,3,2,0}
print(daily_pints_log | wifes_pints_log)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 24, 31}

# %%
print(daily_pints_log & wifes_pints_log)
# Out:
# {1, 2, 3, 5}

# %%
print(daily_pints_log - wifes_pints_log)
# Out:
# {4, 6, 31}

# %%
print(wifes_pints_log-daily_pints_log)
# Out:
# {0, 24, 7}

# %%
print(wifes_pints_log^daily_pints_log)
# Out:
# {0, 4, 6, 7, 24, 31}

# %%
#dictionaries
#key value pair

dict_cream = {'name':'madara uchiha', 'weekly intake':5, 'favourite ice cream': ['mcc','chocolate']}

# %%
type(dict_cream)
# Out:
# dict

# %%
print(dict_cream)
# Out:
# {'name': 'madara uchiha', 'weekly intake': 5, 'favourite ice cream': ['mcc', 'chocolate']}

# %%
dict_cream.values()
# Out:
# dict_values(['madara uchiha', 5, ['mcc', 'chocolate']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'favourite ice cream'])

# %%
dict_cream.items()
# Out:
# dict_items([('name', 'madara uchiha'), ('weekly intake', 5), ('favourite ice cream', ['mcc', 'chocolate'])])

# %%
dict_cream[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 dict_cream[0]
#
# KeyError: 0

# %%
dict_cream["name"]
# Out:
# 'madara uchiha'

# %%
dict_cream['name'] = 'Itachi Uchiha'
print(dict_cream)
# Out:
# {'name': 'Itachi Uchiha', 'weekly intake': 5, 'favourite ice cream': ['mcc', 'chocolate']}

# %%
dict_cream.update({'name': 'Itachi Uchiha', 'weekly intake': 10, 'Weight': 300})
print(dict_cream)
# Out:
# {'name': 'Itachi Uchiha', 'weekly intake': 10, 'favourite ice cream': ['mcc', 'chocolate'], 'Weight': 300}

# %%
del dict_cream['Weight']
print(dict_cream)
# Out:
# {'name': 'Itachi Uchiha', 'weekly intake': 10, 'favourite ice cream': ['mcc', 'chocolate']}

# %%
# comparison
10 == 10
# Out:
# True

# %%
10 != 50
# Out:
# True

# %%
'vanilla' == 'chocolate'
# Out:
# False

# %%
'vanilla' == 'vanilla'
# Out:
# True

# %%
x = 'vanilla'
y = 'chocolate'
x != y
# Out:
# True

# %%
10 <= 50
# Out:
# True

# %%
50 >= 10
# Out:
# True

# %%
#logical operators
(10 > 50) and (50 > 10)
# Out:
# False

# %%
(70 > 50) and (50 > 10)
# Out:
# True

# %%
(10 > 50) or (50 > 10)
# Out:
# True

# %%
('vanilla' > 'chocolate') or (50 > 10)
# Out:
# True

# %%
not ('vanilla' > 'chocolate') or (50 > 10)
# Out:
# True

# %%
#membership operator
ice_cream = 'i love chocolate ice cream'
'love' in ice_cream
# Out:
# True

# %%
scoops = [1,2,3,4,5]
2 in scoops
# Out:
# True

# %%
scoops = [1,2,3,4,5]
wanted_scoops = 8
6 not in scoops
# Out:
# True

# %%
scoops = [1,2,3,4,5]
wanted_scoops = 8
wanted_scoops not in scoops
# Out:
# True

# %%
scoops = [1,2,3,4,5]
wanted_scoops = 8
wanted_scoops in scoops
# Out:
# False

# %%
if 25 > 10:
    print('It worked!')
# Out:
# It worked!

# %%
if 25 < 10 :
    print('it worked!')
else:
    print('it did not work!...')
# Out:
# it did not work!...

# %%
if 25 < 10 :
    print('it worked!')
elif 25 < 20:
    print('elif worked')
elif 25 < 21:
    print('elif 2 worked')
elif 25 < 40:
    print('elif 3 worked')
elif 25 < 50:
    print('elif 4 worked')
else:
    print('it did not work!...')
# Out:
# elif 3 worked

# %%
if (25 < 10) or (1 < 3) :
    print('it worked!')
elif 25 < 20:
    print('elif worked')
elif 25 < 21:
    print('elif 2 worked')
elif 25 < 40:
    print('elif 3 worked')
elif 25 < 50:
    print('elif 4 worked')
else:
    print('it did not work!...')
# Out:
# it worked!

# %%
print('it worked') if 10>30 else print('it did not work...')
# Out:
# it did not work...

# %%
if (25 < 10) or (1 < 3) :
    print('it worked!')
    if 10 > 5 :
        print('this nested if statement worked!')
elif 25 < 20:
    print('elif worked')
elif 25 < 21:
    print('elif 2 worked')
elif 25 < 40:
    print('elif 3 worked')
elif 25 < 50:
    print('elif 4 worked')
else:
    print('it did not work!...')
# Out:
# it worked!
# this nested if statement worked!

# %%
# for loop

integers = [1,2,3,4,5]

for numbers in integers:
    print(numbers)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
integers = [1,2,3,4,5]

for numbers in integers:
    print(numbers,end='')
# Out:
# 12345

# %%
for numbers in integers:
    print('yep!')
# Out:
# yep!
# yep!
# yep!
# yep!
# yep!

# %%
integers = [1,2,3,4,5]
for jelly in integers:
    print(jelly+jelly)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
ice_cream_dict = {'name': 'madara uchiha', 'weekly intake': 5, 'favourite ice cream': ['mcc','chocolate']}
for cream in ice_cream_dict.values():
    print(cream)
# Out:
# madara uchiha
# 5
# ['mcc', 'chocolate']

# %%
for key, values in ice_cream_dict.items():
    print(key, '->',values)
# Out:
# name -> madara uchiha
# weekly intake -> 5
# favourite ice cream -> ['mcc', 'chocolate']

# %%
#nested for loop
flavours = ['vanilla', 'chocolate', 'cookie dough']
toppings = ['hot fudge', 'oreos', 'marshmellows']

for one in flavours:
    for two in toppings:
        print(one,'topped With',two)
# Out:
# vanilla topped With hot fudge
# vanilla topped With oreos
# vanilla topped With marshmellows
# chocolate topped With hot fudge
# chocolate topped With oreos
# chocolate topped With marshmellows
# cookie dough topped With hot fudge
# cookie dough topped With oreos
# cookie dough topped With marshmellows

# %%
number = 0
while number < 5:
    print(number)
    number+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
number = 0
while number < 5:
    print(number)
    if number == 3:
        break
    number+=1
# Out:
# 0
# 1
# 2
# 3

# %%
number = 0
while number < 5:
    print(number)
    if number == 6:
        break
    number+=1
else:
    print('no longer < 5')
# Out:
# 0
# 1
# 2
# 3
# 4
# no longer < 5

# %%
number = 0
while number < 5:
    number+=1
    if number == 3:
        continue
    print(number)
else:
    print('no longer < 5')
# Out:
# 1
# 2
# 4
# 5
# no longer < 5

# %%
# function
def first_func():
    print('we did it!')

# %%
first_func()
# Out:
# we did it!

# %%
def number_squard(number):
    print(number**2)

number_squard(5)
# Out:
# 25

# %%
def number_squard_cust(number,power):
    print(number**power)
number_squard_cust(5,3)
# Out:
# 125

# %%
def number_args(*number):
    print(number[0]*number[1])
number_args(5,6,1,2,8)
# Out:
# 30

# %%
args_tuple = (5,6,1,2,8)
def number_args(*number):
    print(number[0]*number[1])
number_args(*args_tuple)
# Out:
# 30

# %%
def number_squard_cust(number,power):
    print(number**power)
number_squard_cust(power= 5, number= 3)
# Out:
# 243

# %%
def number_kwarg(**number):
    print('my number is:' + number['integer']   +  'my other number:' + number['integer2'])
number_kwarg(integer = '2309', integer2 = '349')
# Out:
# my number is:2309my other number:349

# %%
num_int = 7

type(num_int)
# Out:
# int

# %%
num_str = '7'

type(num_str)
# Out:
# str

# %%
nun_str_conv = int(num_str)
type(nun_str_conv)
# Out:
# int

# %%
num_sum = num_int + nun_str_conv
print(num_sum)
# Out:
# 14

# %%
type(num_sum)
# Out:
# int

# %%
list_type = [1,2,3]
type(list_type)
# Out:
# list

# %%
tuple(list_type)
# Out:
# (1, 2, 3)

# %%
type(tuple(list_type))
# Out:
# tuple

# %%
#aware to convert list it only show unique values
list_type = [1,2,3,3,2,1,3,2,1]
set(list_type)
# Out:
# {1, 2, 3}

# %%
list_type = [1,2,3,3,2,1,3,2,1]
type(set(list_type))
# Out:
# set

# %%
dict_type = {'name': 'Alex', 'age': 28, 'hair': 'n/a'}
type(dict_type)
# Out:
# dict

# %%
dict_type.items()
# Out:
# dict_items([('name', 'Alex'), ('age', 28), ('hair', 'n/a')])

# %%
dict_type.values()
# Out:
# dict_values(['Alex', 28, 'n/a'])

# %%
dict_type.keys()
# Out:
# dict_keys(['name', 'age', 'hair'])

# %%
list(dict_type.keys())
# Out:
# ['name', 'age', 'hair']

# %%
type(list(dict_type.keys()))
# Out:
# list

# %%
type(list(dict_type.values()))
# Out:
# list

# %%
long_string = ' i like to party'
list(long_string)
# Out:
# [' ',
#  'i',
#  ' ',
#  'l',
#  'i',
#  'k',
#  'e',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'p',
#  'a',
#  'r',
#  't',
#  'y']

# %%
long_string = ' i like to party'
set(long_string)
# Out:
# {' ', 'a', 'e', 'i', 'k', 'l', 'o', 'p', 'r', 't', 'y'}

# %%
#bmi calculator
name = input('Enter Your Name:')
weight = int(input("Enter Your Weight in pounds:"))
height = int(input("Enter Your hight in inches:"))

BMI = (weight * 703) / (height * height)
print(BMI)
if BMI >0:
    if(BMI<18.5):
        print(name +",You Are Underweight")
    elif (BMI<=24.5):
        print(name +",You Are normalweight")
    elif (BMI<29.5):
        print(name +",You Are overweight. you need to exercise more")
    elif (BMI<34.9):
        print(name +",You Are obese")
    elif (BMI<39.9):
        print(name +",You Are severely obese")        
    else:
        print(name +",You are morbidly obese")
else:
    print("Enter valid input")
# Out:
# 25.101869355177485
# siva,You Are overweight. you need to exercise more

# %%
if BMI >0:
    if(BMI<18.5):
        print(name +",You Are Underweight")
    elif (BMI<=24.5):
        print(name +",You Are normalweight")
    elif (BMI<29.5):
        print(name +",You Are overweight")
    elif (BMI<34.9):
        print(name +",You Are obese")
    elif (BMI<39.9):
        print(name +",You Are severely obese")        
    else:
        print(name +",You are morbidly obese")
else:
    print("Enter valid input")
# Out:
# siva,You Are overweight

# %%
# file sorter in file explorer

import os, shutil
path = r"C:/Users/SivasankarT/Downloads/Telegram Desktop/File Sorted/"

os.listdir(path)
# Out:
# ['Companies_1.csv',
#  'desktop-wallpaper-pain-naruto-pain-pain-from-naruto.jpg',
#  'FRUITS.txt',
#  'HD-wallpaper-gojo-satoru-jjk-jujutsu-anime-husbando-gojo-satoru-jujutsu-kaisen.jpg']

# %%
os.path.exists(path+ 'csv files')
# Out:
# False

# %%
file_name = os.listdir(path)

# %%
folder_names = ['csv files', 'image file', 'text file']

for loop in range (0,3):
    if not os.path.exists(path+folder_names[loop]):
        print(path+folder_names[loop])
        os.makedirs(path+folder_names[loop])

for file in file_name:
    if ".csv" in file and not os.path.exists(path+ "csv files/" + file):
        shutil.move(path + file, path + "csv files/" + file)
    elif ".txt" in file and not os.path.exists(path+ "text file/" + file):
        shutil.move(path + file, path + "text file/" + file)
    elif ".jpg" in file and not os.path.exists(path+ "image file/" + file):
        shutil.move(path + file, path + "image file/" + file)
    else:
        print("there is files in this path that were not moved")
# Out:
# there is files in this path that were not moved
# there is files in this path that were not moved
# there is files in this path that were not moved
# there is files in this path that were not moved

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\Companies.csv")
df
# Out:
#    Rank                                Name                       Industry  \
# 0     1                             Cargill                  Food industry
# 1     2                     Koch Industries                   Conglomerate
# 2     3                Publix Super Markets                         Retail
# 3     4                  Mars, Incorporated                  Food industry
# 4     5                               H-E-B                         Retail
# 5     6                      Reyes Holdings                    Wholesaling
# 6     7                 Enterprise Holdings                     Car rental
# 7     8               C&S Wholesale Grocers                    Wholesaling
# 8     9                              Love's  Petroleum industry and Retail
# 9    10  Southern Glazer's Wine and Spirits                  Food industry
#
#    Revenue (USD billions) Employees             Headquarters
# 0                   177.0   160,000    Minnetonka, Minnesota
# ...

# %%
df = pd.read_csv(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\FRUITS.txt", sep= '\t')
df
# Out:
#          hi
# 0  byeapple
# 1    orange
# 2     apple
# 3    orange

# %%
# df = pd.read_table(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\FRUITS.txt", sep= '\t')
#df
df = pd.read_table(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\FRUITS.txt", sep = ',')
df
# Out:
#          hi
# 0  byeapple
# 1    orange
# 2     apple
# 3    orange

# %%
import pandas as pd

# %%
del(open)

# %%
file_text = open(r'C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\titanic.json', 'r')

# %%
import json

# %%
file_text = file_text.read()

# %%
file_text.strip('\n')
# Out:
# '{"PassengerId":"1","Survived":"0","Pclass":"3","Name":"Braund, Mr. Owen Harris","Sex":"male","Age":22,"SibSp":"1","Parch":"0","Ticket":"A\\/5 21171","Fare":7.25,"Cabin":null,"Embarked":"S"}\n{"PassengerId":"2","Survived":"1","Pclass":"1","Name":"Cumings, Mrs. John Bradley (Florence Briggs Thayer)","Sex":"female","Age":38,"SibSp":"1","Parch":"0","Ticket":"PC 17599","Fare":71.2833,"Cabin":"C85","Embarked":"C"}\n{"PassengerId":"3","Survived":"1","Pclass":"3","Name":"Heikkinen, Miss. Laina","Sex":"female","Age":26,"SibSp":"0","Parch":"0","Ticket":"STON\\/O2. 3101282","Fare":7.925,"Cabin":null,"Embarked":"S"}\n{"PassengerId":"4","Survived":"1","Pclass":"1","Name":"Futrelle, Mrs. Jacques Heath (Lily May Peel)","Sex":"female","Age":35,"SibSp":"1","Parch":"0","Ticket":"113803","Fare":53.1,"Cabin":"C123","Embarked":"S"}\n{"PassengerId":"5","Survived":"0","Pclass":"3","Name":"Allen, Mr. William Henry","Sex":"male","Age":35,"SibSp":"0","Parch":"0","Ticket":"373450","Fare":8.05,"Cabin":null,"Em
# ...

# %%
json_text = eval(file_text.strip('\n'))
# Out:
# <string>:1: SyntaxWarning: invalid escape sequence '\/'
# Traceback (most recent call last):
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\interactiveshell.py:3549 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[31], line 1
#     json_text = eval(file_text.strip('\n'))
#
#   File <string>:2
#     {"PassengerId":"2","Survived":"1","Pclass":"1","Name":"Cumings, Mrs. John Bradley (Florence Briggs Thayer)","Sex":"female","Age":38,"SibSp":"1","Parch":"0","Ticket":"PC 17599","Fare":71.2833,"Cabin":"C85","Embarked":"C"}
#     ^
# SyntaxError: invalid syntax

# %%
df = pd.json_normalize([{'name':'aple'}])
df
# Out:
#    name
# 0  aple

# %%
df = pd.read_json(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\mtcars.json", lines=True)
df.set_index('model')
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
pd.set_option('display.max.column',150)

# %%
df = pd.read_excel(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\highest_grossing_films.xlsx")
df
# Out:
#     Rank  Peak                                            Title  \
# 0      1     1                                           Avatar
# 1      2     1                                Avengers: Endgame
# 2      3     3                         Avatar: The Way of Water
# 3      4     1                                          Titanic
# 4      5     5                                      Ne Zha 2â€
# 5      6     3                     Star Wars: The Force Awakens
# 6      7     4                           Avengers: Infinity War
# 7      8     6                          Spider-Man: No Way Home
# 8      9     8                                     Inside Out 2
# 9     10     3                                   Jurassic World
# 10    11     7                                    The Lion King
# 11    12     3                                     The Avengers
# 12    13     4                                        Furious 7
# 13    14    11                                Top Gun: Maverick
# ...

# %%
pd.set_option('display.max.rows',49)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             50 non-null     int64
#  1   Peak             50 non-null     object
#  2   Title            50 non-null     object
#  3   Worldwide gross  50 non-null     object
#  4   Year             50 non-null     int64
#  5   Ref              50 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.5+ KB

# %%
df.shape
# Out:
# (50, 6)

# %%
df.head(10)
# Out:
#    Rank Peak                         Title   Worldwide gross  Year  \
# 0     1    1                        Avatar    $2,923,706,026  2009
# 1     2    1             Avengers: Endgame    $2,797,501,328  2019
# 2     3    3      Avatar: The Way of Water    $2,320,250,281  2022
# 3     4    1                       Titanic   T$2,257,844,554  1997
# 4     5    5                   Ne Zha 2â€     $2,127,850,912  2025
# 5     6    3  Star Wars: The Force Awakens    $2,068,223,624  2015
# 6     7    4        Avengers: Infinity War    $2,048,359,754  2018
# 7     8    6       Spider-Man: No Way Home  SM$1,922,598,800  2021
# 8     9    8                  Inside Out 2    $1,698,863,816  2024
# 9    10    3                Jurassic World    $1,671,537,444  2015
#
#             Ref
# 0    [# 1][# 2]
# 1    [# 3][# 4]
# 2    [# 5][# 6]
# 3    [# 7][# 8]
# 4   [# 9][# 10]
# 5  [# 11][# 12]
# 6  [# 13][# 14]
# 7  [# 15][# 16]
# 8  [# 17][# 18]
# 9  [# 19][# 20]

# %%
df.tail(10)
# Out:
#     Rank  Peak                                        Title Worldwide gross  \
# 40    41    30                                  Toy Story 4  $1,073,394,593
# 41    42  4TS3                                  Toy Story 3  $1,066,970,811
# 42    43     3   Pirates of the Caribbean: Dead Man's Chest  $1,066,179,747
# 43    44    44                                   Moana 2â€   $1,059,719,509
# 44    45    20                 Rogue One: A Star Wars Story  $1,057,420,387
# 45    46    34                                      Aladdin  $1,050,693,953
# 46    47     2  Star Wars: Episode I â€“ The Phantom Menace  $1,046,515,409
# 47    48     6  Pirates of the Caribbean: On Stranger Tides  $1,045,713,802
# 48    49     1                                Jurassic Park  $1,037,535,230
# 49    50    24                              Despicable Me 3  $1,034,800,131
#
#     Year           Ref
# 40  2019   [# 70][# 4]
# 41  2010  [# 71][# 72]
# 42  2006  [# 73][# 74]
# 43  2024        [# 75]
# ...

# %%
df['Title']
# Out:
# 0                                          Avatar
# 1                               Avengers: Endgame
# 2                        Avatar: The Way of Water
# 3                                         Titanic
# 4                                     Ne Zha 2â€
#                          ...
# 45                                        Aladdin
# 46    Star Wars: Episode I â€“ The Phantom Menace
# 47    Pirates of the Caribbean: On Stranger Tides
# 48                                  Jurassic Park
# 49                                Despicable Me 3
# Name: Title, Length: 50, dtype: object

# %%
df.loc[40]
# Out:
# Rank                           41
# Peak                           30
# Title                 Toy Story 4
# Worldwide gross    $1,073,394,593
# Year                         2019
# Ref                   [# 70][# 4]
# Name: 40, dtype: object

# %%
df.iloc[40]
# Out:
# Rank                           41
# Peak                           30
# Title                 Toy Story 4
# Worldwide gross    $1,073,394,593
# Year                         2019
# Ref                   [# 70][# 4]
# Name: 40, dtype: object

# %%
# filtering and ordering in pandas
import pandas as pd
df = pd.read_csv(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\Companies.csv")
df
# Out:
#    Rank                                Name                       Industry  \
# 0     1                             Cargill                  Food industry
# 1     2                     Koch Industries                   Conglomerate
# 2     3                Publix Super Markets                         Retail
# 3     4                  Mars, Incorporated                  Food industry
# 4     5                               H-E-B                         Retail
# 5     6                      Reyes Holdings                    Wholesaling
# 6     7                 Enterprise Holdings                     Car rental
# 7     8               C&S Wholesale Grocers                    Wholesaling
# 8     9                              Love's  Petroleum industry and Retail
# 9    10  Southern Glazer's Wine and Spirits                  Food industry
#
#    Revenue (USD billions) Employees             Headquarters
# 0                   177.0   160,000    Minnetonka, Minnesota
# ...

# %%
df[df['Rank'] <=5 ]
# Out:
#    Rank                  Name       Industry  Revenue (USD billions)  \
# 0     1               Cargill  Food industry                   177.0
# 1     2       Koch Industries   Conglomerate                   125.0
# 2     3  Publix Super Markets         Retail                    54.5
# 3     4    Mars, Incorporated  Food industry                    47.0
# 4     5                 H-E-B         Retail                    43.6
#
#   Employees           Headquarters
# 0   160,000  Minnetonka, Minnesota
# 1   120,000        Wichita, Kansas
# 2   250,000      Lakeland, Florida
# 3   140,000       McLean, Virginia
# 4   145,000     San Antonio, Texas

# %%
specific_industry = ['Retail','Conglomerate']
df[df['Industry'].isin(specific_industry)]
# Out:
#    Rank                  Name      Industry  Revenue (USD billions) Employees  \
# 1     2       Koch Industries  Conglomerate                   125.0   120,000
# 2     3  Publix Super Markets        Retail                    54.5   250,000
# 4     5                 H-E-B        Retail                    43.6   145,000
#
#          Headquarters
# 1     Wichita, Kansas
# 2   Lakeland, Florida
# 4  San Antonio, Texas

# %%
df[df['Headquarters'].str.contains('Kansas')]
# Out:
#    Rank             Name      Industry  Revenue (USD billions) Employees  \
# 1     2  Koch Industries  Conglomerate                   125.0   120,000
#
#       Headquarters
# 1  Wichita, Kansas

# %%
df2 = df.set_index('Industry')
df2
# Out:
#                                Rank                                Name  \
# Industry
# Food industry                     1                             Cargill
# Conglomerate                      2                     Koch Industries
# Retail                            3                Publix Super Markets
# Food industry                     4                  Mars, Incorporated
# Retail                            5                               H-E-B
# Wholesaling                       6                      Reyes Holdings
# Car rental                        7                 Enterprise Holdings
# Wholesaling                       8               C&S Wholesale Grocers
# Petroleum industry and Retail     9                              Love's
# Food industry                    10  Southern Glazer's Wine and Spirits
#
#                                Revenue (USD billions) Employees  \
# Industry
# Food industry                                   177.0   160,000
# ...

# %%
df2.filter(items= ['Name','Rank'])
# Out:
#                                                              Name  Rank
# Industry
# Food industry                                             Cargill     1
# Conglomerate                                      Koch Industries     2
# Retail                                       Publix Super Markets     3
# Food industry                                  Mars, Incorporated     4
# Retail                                                      H-E-B     5
# Wholesaling                                        Reyes Holdings     6
# Car rental                                    Enterprise Holdings     7
# Wholesaling                                 C&S Wholesale Grocers     8
# Petroleum industry and Retail                              Love's     9
# Food industry                  Southern Glazer's Wine and Spirits    10

# %%
df.filter(items = ['car rental'], axis = 0)
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD billions), Employees, Headquarters]
# Index: []

# %%
df2.filter(like= 'Car rental', axis = 0)
# Out:
#             Rank                 Name  Revenue (USD billions) Employees  \
# Industry
# Car rental     7  Enterprise Holdings                    35.0    90,000
#
#                  Headquarters
# Industry
# Car rental  Clayton, Missouri

# %%
df2.loc['Car rental']
# Out:
# Rank                                        7
# Name                      Enterprise Holdings
# Revenue (USD billions)                   35.0
# Employees                              90,000
# Headquarters                Clayton, Missouri
# Name: Car rental, dtype: object

# %%
df2.iloc[3]
# Out:
# Rank                                       4
# Name                      Mars, Incorporated
# Revenue (USD billions)                  47.0
# Employees                            140,000
# Headquarters                McLean, Virginia
# Name: Food industry, dtype: object

# %%
#Ascending order
df[df['Rank'] < 5].sort_values(by='Rank')
# Out:
#    Rank                  Name       Industry  Revenue (USD billions)  \
# 0     1               Cargill  Food industry                   177.0
# 1     2       Koch Industries   Conglomerate                   125.0
# 2     3  Publix Super Markets         Retail                    54.5
# 3     4    Mars, Incorporated  Food industry                    47.0
#
#   Employees           Headquarters
# 0   160,000  Minnetonka, Minnesota
# 1   120,000        Wichita, Kansas
# 2   250,000      Lakeland, Florida
# 3   140,000       McLean, Virginia

# %%
df[df['Rank'] < 5].sort_values(by='Rank',ascending=False)
# Out:
#    Rank                  Name       Industry  Revenue (USD billions)  \
# 3     4    Mars, Incorporated  Food industry                    47.0
# 2     3  Publix Super Markets         Retail                    54.5
# 1     2       Koch Industries   Conglomerate                   125.0
# 0     1               Cargill  Food industry                   177.0
#
#   Employees           Headquarters
# 3   140,000       McLean, Virginia
# 2   250,000      Lakeland, Florida
# 1   120,000        Wichita, Kansas
# 0   160,000  Minnetonka, Minnesota

# %%
df[df['Rank'] < 5].sort_values(by=['Rank','Industry'],ascending=False)
# Out:
#    Rank                  Name       Industry  Revenue (USD billions)  \
# 3     4    Mars, Incorporated  Food industry                    47.0
# 2     3  Publix Super Markets         Retail                    54.5
# 1     2       Koch Industries   Conglomerate                   125.0
# 0     1               Cargill  Food industry                   177.0
#
#   Employees           Headquarters
# 3   140,000       McLean, Virginia
# 2   250,000      Lakeland, Florida
# 1   120,000        Wichita, Kansas
# 0   160,000  Minnetonka, Minnesota

# %%
df[df['Rank'] < 5].sort_values(by=['Industry','Rank'],ascending=False)
# Out:
#    Rank                  Name       Industry  Revenue (USD billions)  \
# 2     3  Publix Super Markets         Retail                    54.5
# 3     4    Mars, Incorporated  Food industry                    47.0
# 0     1               Cargill  Food industry                   177.0
# 1     2       Koch Industries   Conglomerate                   125.0
#
#   Employees           Headquarters
# 2   250,000      Lakeland, Florida
# 3   140,000       McLean, Virginia
# 0   160,000  Minnetonka, Minnesota
# 1   120,000        Wichita, Kansas

# %%
df[df['Rank'] < 5].sort_values(by=['Name','Rank'],ascending=False)
# Out:
#    Rank                  Name       Industry  Revenue (USD billions)  \
# 2     3  Publix Super Markets         Retail                    54.5
# 3     4    Mars, Incorporated  Food industry                    47.0
# 1     2       Koch Industries   Conglomerate                   125.0
# 0     1               Cargill  Food industry                   177.0
#
#   Employees           Headquarters
# 2   250,000      Lakeland, Florida
# 3   140,000       McLean, Virginia
# 1   120,000        Wichita, Kansas
# 0   160,000  Minnetonka, Minnesota

# %%
df[df['Rank'] < 5].sort_values(by=['Name','Rank'],ascending=[False,True])
# Out:
#    Rank                  Name       Industry  Revenue (USD billions)  \
# 2     3  Publix Super Markets         Retail                    54.5
# 3     4    Mars, Incorporated  Food industry                    47.0
# 1     2       Koch Industries   Conglomerate                   125.0
# 0     1               Cargill  Food industry                   177.0
#
#   Employees           Headquarters
# 2   250,000      Lakeland, Florida
# 3   140,000       McLean, Virginia
# 1   120,000        Wichita, Kansas
# 0   160,000  Minnetonka, Minnesota

# %%
# indexes
import pandas as pd
df = pd.read_csv(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\Companies.csv")
df
# Out:
#    Rank                                Name                       Industry  \
# 0     1                             Cargill                  Food industry
# 1     2                     Koch Industries                   Conglomerate
# 2     3                Publix Super Markets                         Retail
# 3     4                  Mars, Incorporated                  Food industry
# 4     5                               H-E-B                         Retail
# 5     6                      Reyes Holdings                    Wholesaling
# 6     7                 Enterprise Holdings                     Car rental
# 7     8               C&S Wholesale Grocers                    Wholesaling
# 8     9                              Love's  Petroleum industry and Retail
# 9    10  Southern Glazer's Wine and Spirits                  Food industry
#
#    Revenue (USD billions) Employees             Headquarters
# 0                   177.0   160,000    Minnetonka, Minnesota
# ...

# %%
df = pd.read_csv(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\Companies.csv", index_col= 'Name')
df
# Out:
#                                     Rank                       Industry  \
# Name
# Cargill                                1                  Food industry
# Koch Industries                        2                   Conglomerate
# Publix Super Markets                   3                         Retail
# Mars, Incorporated                     4                  Food industry
# H-E-B                                  5                         Retail
# Reyes Holdings                         6                    Wholesaling
# Enterprise Holdings                    7                     Car rental
# C&S Wholesale Grocers                  8                    Wholesaling
# Love's                                 9  Petroleum industry and Retail
# Southern Glazer's Wine and Spirits    10                  Food industry
#
#                                     Revenue (USD billions) Employees  \
# Name
# Cargill                                              177.0   160,000
# ...

# %%
# Reverse Index
df.reset_index(inplace=True)
df
# Out:
#                                  Name  Rank                       Industry  \
# 0                             Cargill     1                  Food industry
# 1                     Koch Industries     2                   Conglomerate
# 2                Publix Super Markets     3                         Retail
# 3                  Mars, Incorporated     4                  Food industry
# 4                               H-E-B     5                         Retail
# 5                      Reyes Holdings     6                    Wholesaling
# 6                 Enterprise Holdings     7                     Car rental
# 7               C&S Wholesale Grocers     8                    Wholesaling
# 8                              Love's     9  Petroleum industry and Retail
# 9  Southern Glazer's Wine and Spirits    10                  Food industry
#
#    Revenue (USD billions) Employees             Headquarters
# 0                   177.0   160,000    Minnetonka, Minnesota
# ...

# %%
df.set_index('Name',inplace=True)
df
# Out:
#                                     Rank                       Industry  \
# Name
# Cargill                                1                  Food industry
# Koch Industries                        2                   Conglomerate
# Publix Super Markets                   3                         Retail
# Mars, Incorporated                     4                  Food industry
# H-E-B                                  5                         Retail
# Reyes Holdings                         6                    Wholesaling
# Enterprise Holdings                    7                     Car rental
# C&S Wholesale Grocers                  8                    Wholesaling
# Love's                                 9  Petroleum industry and Retail
# Southern Glazer's Wine and Spirits    10                  Food industry
#
#                                     Revenue (USD billions) Employees  \
# Name
# Cargill                                              177.0   160,000
# ...

# %%
df.loc['Cargill']
# Out:
# Rank                                          1
# Industry                          Food industry
# Revenue (USD billions)                    177.0
# Employees                               160,000
# Headquarters              Minnetonka, Minnesota
# Name: Cargill, dtype: object

# %%
df.iloc[0]
# Out:
# Rank                                          1
# Industry                          Food industry
# Revenue (USD billions)                    177.0
# Employees                               160,000
# Headquarters              Minnetonka, Minnesota
# Name: Cargill, dtype: object

# %%
#multi index
df.reset_index(inplace=True)
df
# Out:
#    index                                Name  Rank  \
# 0      0                             Cargill     1
# 1      1                     Koch Industries     2
# 2      2                Publix Super Markets     3
# 3      3                  Mars, Incorporated     4
# 4      4                               H-E-B     5
# 5      5                      Reyes Holdings     6
# 6      6                 Enterprise Holdings     7
# 7      7               C&S Wholesale Grocers     8
# 8      8                              Love's     9
# 9      9  Southern Glazer's Wine and Spirits    10
#
#                         Industry  Revenue (USD billions) Employees  \
# 0                  Food industry                   177.0   160,000
# 1                   Conglomerate                   125.0   120,000
# 2                         Retail                    54.5   250,000
# 3                  Food industry                    47.0   140,000
# ...

# %%
df.reset_index(inplace=True)
df.set_index(['Name','Industry'], inplace=True)
df
# Out:
#                                                                   index  Rank  \
# Name                               Industry
# Cargill                            Food industry                      0     1
# Koch Industries                    Conglomerate                       1     2
# Publix Super Markets               Retail                             2     3
# Mars, Incorporated                 Food industry                      3     4
# H-E-B                              Retail                             4     5
# Reyes Holdings                     Wholesaling                        5     6
# Enterprise Holdings                Car rental                         6     7
# C&S Wholesale Grocers              Wholesaling                        7     8
# Love's                             Petroleum industry and Retail      8     9
# Southern Glazer's Wine and Spirits Food industry                      9    10
#
# ...

# %%
#ascending Order
df.reset_index(inplace=True)
df.set_index(['Name','Industry'], inplace=True)

# %%
df.sort_index()
#pd.set_option('display.max.columns',8)
# Out:
#                                                                   index  Rank  \
# Name                               Industry
# C&S Wholesale Grocers              Wholesaling                        7     8
# Cargill                            Food industry                      0     1
# Enterprise Holdings                Car rental                         6     7
# H-E-B                              Retail                             4     5
# Koch Industries                    Conglomerate                       1     2
# Love's                             Petroleum industry and Retail      8     9
# Mars, Incorporated                 Food industry                      3     4
# Publix Super Markets               Retail                             2     3
# Reyes Holdings                     Wholesaling                        5     6
# Southern Glazer's Wine and Spirits Food industry                      9    10
#
# ...

# %%
df.sort_index(ascending=[False, True])
#pd.set_option('display.max.columns',8)
# Out:
#                                                                   index  Rank  \
# Name                               Industry
# Southern Glazer's Wine and Spirits Food industry                      9    10
# Reyes Holdings                     Wholesaling                        5     6
# Publix Super Markets               Retail                             2     3
# Mars, Incorporated                 Food industry                      3     4
# Love's                             Petroleum industry and Retail      8     9
# Koch Industries                    Conglomerate                       1     2
# H-E-B                              Retail                             4     5
# Enterprise Holdings                Car rental                         6     7
# Cargill                            Food industry                      0     1
# C&S Wholesale Grocers              Wholesaling                        7     8
#
# ...

# %%
df.loc['Cargill']
# Out:
#                index  Rank  Revenue (USD billions) Employees  \
# Industry
# Food industry      0     1                   177.0   160,000
#
#                         Headquarters
# Industry
# Food industry  Minnetonka, Minnesota

# %%
df.loc['Cargill','Food industry']
# Out:
# index                                         0
# Rank                                          1
# Revenue (USD billions)                    177.0
# Employees                               160,000
# Headquarters              Minnetonka, Minnesota
# Name: (Cargill, Food industry), dtype: object

# %%
df.iloc[0]
# Out:
# index                                         0
# Rank                                          1
# Revenue (USD billions)                    177.0
# Employees                               160,000
# Headquarters              Minnetonka, Minnesota
# Name: (Cargill, Food industry), dtype: object

# %%
#Group by And aggregating

import pandas as pd
df = pd.read_csv(r"C:\Users\SivasankarT\Downloads\Flavors (2).csv")
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
group_by_frame = df.groupby('Base Flavor')

# %%
group_by_frame.min()
# Out:
#                   Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
print(df.dtypes)
# Out:
# Flavor             object
# Base Flavor        object
# Liked              object
# Flavor Rating     float64
# Texture Rating    float64
# Total Rating      float64
# dtype: object

# %%
df.groupby('Base Flavor').agg({'Flavor Rating':['mean']})
# Out:
#             Flavor Rating
#                      mean
# Base Flavor
# Chocolate             8.4
# Vanilla               5.7

# %%
df.groupby('Base Flavor').min()
# Out:
#                   Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
df.groupby('Base Flavor').count()
# Out:
#              Flavor  Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
df.groupby('Base Flavor').max()
# Out:
#                  Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate    Rocky Road   Yes            8.8             7.6          16.6
# Vanilla         Vanilla   Yes           10.0             8.0          18.0

# %%
df.groupby('Base Flavor').sum()
# Out:
#                                                         Flavor  \
# Base Flavor
# Chocolate            ChocolateRocky RoadChocolte Fudge Brownie
# Vanilla      Mint Chocolate ChipVanillaCookie DoughPistachi...
#
#                        Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate          YesYesYes           25.2            21.7          47.1
# Vanilla      YesNoYesNoYesNo           34.2            33.9          68.1

# %%
df.groupby('Base Flavor').sum()
# Out:
#                                                         Flavor  \
# Base Flavor
# Chocolate            ChocolateRocky RoadChocolte Fudge Brownie
# Vanilla      Mint Chocolate ChipVanillaCookie DoughPistachi...
#
#                        Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate          YesYesYes           25.2            21.7          47.1
# Vanilla      YesNoYesNoYesNo           34.2            33.9          68.1

# %%
df.groupby('Base Flavor').agg({'Flavor Rating': ['mean','max','count','sum']})
# Out:
#             Flavor Rating
#                      mean   max count   sum
# Base Flavor
# Chocolate             8.4   8.8     3  25.2
# Vanilla               5.7  10.0     6  34.2

# %%
df.groupby('Base Flavor').agg({'Flavor Rating': ['mean','max','count','sum'], 'Texture Rating':['mean','max','count','sum']})
# Out:
#             Flavor Rating                   Texture Rating
#                      mean   max count   sum           mean  max count   sum
# Base Flavor
# Chocolate             8.4   8.8     3  25.2       7.233333  7.6     3  21.7
# Vanilla               5.7  10.0     6  34.2       5.650000  8.0     6  33.9

# %%
df.groupby(['Base Flavor','Liked']).max()
# Out:
#                                 Flavor  Flavor Rating  Texture Rating  \
# Base Flavor Liked
# Chocolate   Yes             Rocky Road            8.8             7.6
# Vanilla     No                 Vanilla            4.7             5.0
#             Yes    Mint Chocolate Chip           10.0             8.0
#
#                    Total Rating
# Base Flavor Liked
# Chocolate   Yes            16.6
# Vanilla     No              9.7
#             Yes            18.0

# %%
df.groupby(['Base Flavor','Liked']).agg({'Flavor Rating': ['mean','max','count','sum']})
# Out:
#                   Flavor Rating
#                            mean   max count   sum
# Base Flavor Liked
# Chocolate   Yes             8.4   8.8     3  25.2
# Vanilla     No              3.6   4.7     3  10.8
#             Yes             7.8  10.0     3  23.4

# %%
df.groupby(['Base Flavor']).describe()
# Out:
#             Flavor Rating                                             \
#                     count mean       std  min    25%  50%  75%   max
# Base Flavor
# Chocolate             3.0  8.4  0.346410  8.2  8.200  8.2  8.5   8.8
# Vanilla               6.0  5.7  2.710719  2.3  4.025  5.6  6.8  10.0
#
#             Texture Rating            ...             Total Rating         \
#                      count      mean  ...    75%  max        count   mean
# Base Flavor                           ...
# Chocolate              3.0  7.233333  ...  7.350  7.6          3.0  15.70
# Vanilla                6.0  5.650000  ...  6.375  8.0          6.0  11.35
#
#
#                   std   min     25%   50%     75%   max
# Base Flavor
# Chocolate    0.781025  15.2  15.250  15.3  15.950  16.6
# Vanilla      4.263684   5.7   9.025  11.1  13.175  18.0
#
# [2 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Flavor          9 non-null      object
#  1   Base Flavor     9 non-null      object
#  2   Liked           9 non-null      object
#  3   Flavor Rating   9 non-null      float64
#  4   Texture Rating  9 non-null      float64
#  5   Total Rating    9 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 564.0+ bytes

# %%
#Merging Data Frames
import pandas as pd 
df1 = pd.read_csv(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\LOTR.csv")
df1
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
df2 = pd.read_csv(r"C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\LOTR 2.csv")
df2
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
# Merge coz have only 2 similar Dataset 1001,1002
df1.merge(df2)
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
df1.merge(df2, how= 'inner',on=['FellowshipID','FirstName'])
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
df1.merge(df2, how= 'outer')
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
df1.merge(df2, how= 'left')
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding  50.0
# 1          1002   Samwise  Gardening  39.0
# 2          1003   Gandalf     Spells   NaN
# 3          1004    Pippin  Fireworks   NaN

# %%
df1.merge(df2, how= 'right')
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding    50
# 1          1002   Samwise  Gardening    39
# 2          1006   Legolas        NaN  2931
# 3          1007    Elrond        NaN  6520
# 4          1008  Barromir        NaN    51

# %%
df1.merge(df2, how= 'cross')
# Out:
#     FellowshipID_x FirstName_x     Skills  FellowshipID_y FirstName_y   Age
# 0             1001       Frodo     Hiding            1001       Frodo    50
# 1             1001       Frodo     Hiding            1002     Samwise    39
# 2             1001       Frodo     Hiding            1006     Legolas  2931
# 3             1001       Frodo     Hiding            1007      Elrond  6520
# 4             1001       Frodo     Hiding            1008    Barromir    51
# 5             1002     Samwise  Gardening            1001       Frodo    50
# 6             1002     Samwise  Gardening            1002     Samwise    39
# 7             1002     Samwise  Gardening            1006     Legolas  2931
# 8             1002     Samwise  Gardening            1007      Elrond  6520
# 9             1002     Samwise  Gardening            1008    Barromir    51
# 10            1003     Gandalf     Spells            1001       Frodo    50
# ...

# %%
# join Dataframes
df1.join(df2, on='FellowshipID', how= 'outer', lsuffix= '_left',rsuffix='_right')
# Out:
#      FellowshipID  FellowshipID_left FirstName_left     Skills  \
# NaN             0                NaN            NaN        NaN
# NaN             1                NaN            NaN        NaN
# NaN             2                NaN            NaN        NaN
# NaN             3                NaN            NaN        NaN
# NaN             4                NaN            NaN        NaN
# 0.0          1001             1001.0          Frodo     Hiding
# 1.0          1002             1002.0        Samwise  Gardening
# 2.0          1003             1003.0        Gandalf     Spells
# 3.0          1004             1004.0         Pippin  Fireworks
#
#      FellowshipID_right FirstName_right     Age
# NaN              1001.0           Frodo    50.0
# NaN              1002.0         Samwise    39.0
# NaN              1006.0         Legolas  2931.0
# NaN              1007.0          Elrond  6520.0
# NaN              1008.0        Barromir    51.0
# ...

# %%
df4 = df1.set_index('FellowshipID').join(df2.set_index('FellowshipID'),lsuffix= '_left',rsuffix='_right')
df4
# Out:
#              FirstName_left     Skills FirstName_right   Age
# FellowshipID
# 1001                  Frodo     Hiding           Frodo  50.0
# 1002                Samwise  Gardening         Samwise  39.0
# 1003                Gandalf     Spells             NaN   NaN
# 1004                 Pippin  Fireworks             NaN   NaN

# %%
df4 = df1.set_index('FellowshipID').join(df2.set_index('FellowshipID'),lsuffix= '_left',rsuffix='_right', how='outer')
df4
# Out:
#              FirstName_left     Skills FirstName_right     Age
# FellowshipID
# 1001                  Frodo     Hiding           Frodo    50.0
# 1002                Samwise  Gardening         Samwise    39.0
# 1003                Gandalf     Spells             NaN     NaN
# 1004                 Pippin  Fireworks             NaN     NaN
# 1006                    NaN        NaN         Legolas  2931.0
# 1007                    NaN        NaN          Elrond  6520.0
# 1008                    NaN        NaN        Barromir    51.0

# %%
# oncatinate
pd.concat([df1,df2])
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %%
pd.concat([df1,df2], join='inner')
# Out:
#    FellowshipID FirstName
# 0          1001     Frodo
# 1          1002   Samwise
# 2          1003   Gandalf
# 3          1004    Pippin
# 0          1001     Frodo
# 1          1002   Samwise
# 2          1006   Legolas
# 3          1007    Elrond
# 4          1008  Barromir

# %%
pd.concat([df1,df2], join='outer')
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %%
pd.concat([df1,df2], join='outer', axis=1)
# Out:
#    FellowshipID FirstName     Skills  FellowshipID FirstName   Age
# 0        1001.0     Frodo     Hiding          1001     Frodo    50
# 1        1002.0   Samwise  Gardening          1002   Samwise    39
# 2        1003.0   Gandalf     Spells          1006   Legolas  2931
# 3        1004.0    Pippin  Fireworks          1007    Elrond  6520
# 4           NaN       NaN        NaN          1008  Barromir    51

# %%
# it doesn't work coz pandas removed append Query
df1.append(df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15404\983071838.py in ?()
#       1 # it doesn't work coz pandas removed append Query
# ----> 2 df1.append(df2)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# pandas visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\SivasankarT\Downloads\Ice Cream Ratings.csv")
df = df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind='line',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
print(plt.style.available)
plt.style.use('fivethirtyeight')
# we can use below option Styles to Map for multiple Colors
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.plot(kind='line',title='Ice Cream Rating',xlabel='daily Rating',ylabel='Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='daily Rating', ylabel='Scores'>

# %%
df.plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.barh(stacked=True)
# Out:
# <Axes: ylabel='Date'>

# %%
#s=500 size c use for color
df.plot.scatter(x = 'Texture Rating',y = 'Overall Rating',s = 500, c= 'yellow')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
# bins=10 was barchart size
df.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y='Overall Rating',figsize=(10,5))
# Out:
# <Axes: ylabel='Overall Rating'>

# %%
import pandas as pd
df =pd.read_excel(r"C:\Users\SivasankarT\Downloads\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# for drop columns
df=df.drop(columns='Not_Useful_Column')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name'].str.strip()
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
# using.lstrip for remove left side 
df['Last_Name'].str.lstrip('...')
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'] = df['Last_Name'].str.lstrip('...')
df['Last_Name'] = df['Last_Name'].str.lstrip('/')
df['Last_Name'] = df['Last_Name'].str.rstrip('_')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
# easyway to remove
df['Last_Name'] = df['Last_Name'].str.strip('123._/')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
# change mob no type
df['Phone_Number'] =df['Phone_Number'].str.replace('[^a-zA-Z0-9]','',regex=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          NaN
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          NaN
# 11        1012      Harry      Potter          NaN
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
df['Phone_Number'].apply(lambda x: str(x))
# Out:
# 0     1235455421
# 1     1236439775
# 2            nan
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            nan
# 7     8766783469
# 8             Na
# 9     1235455421
# 10           nan
# 11           nan
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17           nan
# 18            Na
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'] = df['Phone_Number'].apply(
    lambda x: str(int(x)) if isinstance(x, float) and not pd.isna(x) else str(x)
)

df['Phone_Number'] = df['Phone_Number'].apply(
    lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10] if x.isdigit() and len(x) >= 10 else x
)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White           nan
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           nan
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN            Na
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           nan
# 11        1012      Harry      Potter           nan
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df['Phone_Number']=df['Phone_Number'].apply( lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10] if x.isdigit() and len(x) >= 10 else x
)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White           nan
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           nan
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN            Na
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           nan
# 11        1012      Harry      Potter           nan
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df['Phone_Number']=df['Phone_Number'].str.replace('nan','')

df['Phone_Number']=df['Phone_Number'].str.replace('Na','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df['Address'].str.split(',', n=2, expand=True)
# Out:
#                        0              1       2
# 0         123 Shire Lane          Shire    None
# 1    93 West Main Street           None    None
# 2     298 Drugs Driveway           None    None
# 3       980 Paper Avenue   Pennsylvania   18503
# 4       123 Dragons Road           None    None
# 5       768 City Parkway           None    None
# 6      1209 South Street           None    None
# 7          98 Clue Drive           None    None
# 8       123 Middle Earth           None    None
# 9       25th Main Street       New York    None
# 10        612 Shire Lane          Shire    None
# 11  2394 Hogwarts Avenue           None    None
# 12      2039 Main Street           None    None
# 13      343 City Parkway           None    None
# 14         214 HR Avenue           None    None
# 15  2395 Hogwarts Avenue           None    None
# 16      121 Paper Avenue   Pennsylvania    None
# 17       3498 Super Lane           None    None
# 18                   N/a           None    None
# ...

# %%
df[['Street_Address','State','Zip_Code']]= df['Address'].str.split(',', n=2, expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df['Paying Customer'] = df['Paying Customer'].str.replace('Yes','y')
df['Paying Customer'] = df['Paying Customer'].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('Yes','y')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df = df.replace('N/a','')
# df = df.replace('NaN','') df is null value so we cant replace it
df= df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
for x in df.index:
    if df.loc[x, 'Do_Not_Contact'] =='Y':
        df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White
# 4         1005        Jon        Snow  876-678-3469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               y              N
# ...

# %%
for x in df.index:
    if df.loc[x, 'Phone_Number'] =='':
        df.drop(x, inplace=True)
df
#another way to drop null values
#df.dropna(subset='Phone_Number'), inplace=True
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 4         1005        Jon        Snow  876-678-3469
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               y              N
# 4                 123 Dragons Road               Y              N
# 7                    98 Clue Drive               N              N
# 9       25th Main Street, New York               y              N
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number  \
# 0        1001      Frodo     Baggins  123-545-5421
# 1        1005        Jon        Snow  876-678-3469
# 2        1008   Sherlock      Holmes  876-678-3469
# 3        1010      Peter      Parker  123-545-5421
# 4        1013        Don      Draper  123-543-2345
# 5        1014     Leslie       Knope  876-678-3469
# 6        1015       Toby  Flenderson  304-762-2467
# 7        1016        Ron     Weasley  123-545-5421
# 8        1017   Michael        Scott  123-643-9775
# 9        1020     Anakin   Skywalker  876-678-3469
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# 3      25th Main Street, New York               y              N
# 4                2039 Main Street               y              N
# ...

# %%
df.to_csv(r'C:\Users\SivasankarT\Downloads\Telegram Desktop\pandas file\dataclean_file.csv')

# %%
# EDA data analysis in pandas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\SivasankarT\Downloads\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.300000e+02     2.330000e+02     2.300000e+02
# mean   117.500000     3.463225e+07     3.360071e+07     3.206600e+07
# std     67.694165     1.378892e+08     1.358732e+08     1.315071e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.064710e+05     3.942950e+05
# 50%    117.500000     5.762857e+06     5.456681e+06     5.244415e+06
# 75%    175.750000     2.265372e+07     2.152263e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.270000e+02     2.270000e+02     2.290000e+02     2.290000e+02
# mean      3.027016e+07     2.684050e+07     1.933046e+07     1.628288e+07
# std       1.260742e+08     1.133525e+08     8.130962e+07     6.934547e+07
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
df.sort_values(by="2022 Population").head()
# Out:
#      Rank CCA3           Country       Capital      Continent  \
# 226   234  VAT      Vatican City  Vatican City         Europe
# 209   233  TKL           Tokelau      Nukunonu        Oceania
# 150   232  NIU              Niue         Alofi        Oceania
# 64    231  FLK  Falkland Islands       Stanley  South America
# 137   230  MSR        Montserrat        Brades  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 226            510.0            520.0            564.0            596.0
# 209           1871.0           1827.0           1454.0           1367.0
# 150           1934.0           1942.0           1847.0           1812.0
# 64            3780.0           3747.0           3408.0           3187.0
# 137           4390.0           4500.0           5059.0           4938.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 226            651.0            700.0            733.0            752.0
# ...

# %%
df.sort_values(by="2022 Population",ascending=False).head()
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# 221     3.382899e+08     3.359420e+08     3.246078e+08     3.111828e+08
# 93      2.755013e+08     2.718580e+08     2.590920e+08     2.440162e+08
# 156     2.358249e+08     2.271967e+08     2.109693e+08     1.944545e+08
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 41      1.264099e+09     1.153704e+09      982372466.0      822534450.0
# ...

# %%
df.sort_values(by="2022 Population",ascending=False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# ...

# %%
df.sort_values(by="World Population Percentage",ascending=False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                  Rank  2022 Population  2020 Population  \
# Rank                         1.000000        -0.357989        -0.356283
# 2022 Population             -0.357989         1.000000         0.999946
# 2020 Population             -0.356283         0.999946         1.000000
# 2015 Population             -0.352850         0.999492         0.999764
# 2010 Population             -0.350009         0.998633         0.999108
# 2000 Population             -0.342095         0.994602         0.995582
# 1990 Population             -0.333014         0.991124         0.992557
# 1980 Population             -0.328620         0.986675         0.988392
# 1970 Population             -0.335737         0.973135         0.975245
# Area (km²)                  -0.384854         0.452812         0.454902
# Density (per km²)            0.128994        -0.028761        -0.027802
# Growth Rate                 -0.220197        -0.022059        -0.025976
# ...

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.rcParams['figure.figsize'] = (20,8)
plt.show()

# %%
# If your df has columns like 'Country', 'Continent', or 'Status', those are strings and can’t be averaged.
df.groupby('Continent')[df.select_dtypes(include='number').columns].mean().sort_values(by='2022 Population',ascending=False)
# Out:
#                      Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia            77.560000     9.632739e+07     9.495513e+07     8.916500e+07
# South America   97.571429     3.120119e+07     3.082357e+07     2.950960e+07
# Africa          92.157895     2.545588e+07     2.387144e+07     2.141970e+07
# Europe         124.500000     1.505537e+07     1.491584e+07     1.502745e+07
# North America  160.925000     1.500740e+07     1.485591e+07     1.425960e+07
# Oceania        188.521739     2.046386e+06     1.910149e+06     1.756664e+06
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia              8.908777e+07     8.058084e+07     4.864000e+07
# South America     2.678940e+07     2.501589e+07     2.122474e+07
# Africa            1.889820e+07     1.459837e+07     1.137696e+07
# Europe            1.471228e+07     1.481769e+07     1.478520e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# ...

# %%
df2 = df.groupby('Continent')[df.select_dtypes(include='number').columns].mean().sort_values(by='2022 Population',ascending=False)
df2
# Out:
#                      Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia            77.560000     9.632739e+07     9.495513e+07     8.916500e+07
# South America   97.571429     3.120119e+07     3.082357e+07     2.950960e+07
# Africa          92.157895     2.545588e+07     2.387144e+07     2.141970e+07
# Europe         124.500000     1.505537e+07     1.491584e+07     1.502745e+07
# North America  160.925000     1.500740e+07     1.485591e+07     1.425960e+07
# Oceania        188.521739     2.046386e+06     1.910149e+06     1.756664e+06
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia              8.908777e+07     8.058084e+07     4.864000e+07
# South America     2.678940e+07     2.501589e+07     2.122474e+07
# Africa            1.889820e+07     1.459837e+07     1.137696e+07
# Europe            1.471228e+07     1.481769e+07     1.478520e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# ...

# %%
# Step 1: Choose numeric columns between index 5 and 13
numeric_cols = df.select_dtypes(include='number').columns
selected_cols = df.columns[5:13]
final_cols = selected_cols.intersection(numeric_cols)

# Step 2: Group and compute mean
df2 = df.groupby('Continent')[final_cols].mean()

# Step 3: Sort by 2022 Population (if it exists)
if '2022 Population' in df2.columns:
    df2 = df2.sort_values(by='2022 Population', ascending=False)

df2
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia              9.632739e+07     9.495513e+07     8.916500e+07
# South America     3.120119e+07     3.082357e+07     2.950960e+07
# Africa            2.545588e+07     2.387144e+07     2.141970e+07
# Europe            1.505537e+07     1.491584e+07     1.502745e+07
# North America     1.500740e+07     1.485591e+07     1.425960e+07
# Oceania           2.046386e+06     1.910149e+06     1.756664e+06
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia              8.908777e+07     8.058084e+07     4.864000e+07
# South America     2.678940e+07     2.501589e+07     2.122474e+07
# Africa            1.889820e+07     1.459837e+07     1.137696e+07
# Europe            1.471228e+07     1.481769e+07     1.478520e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# Oceania           1.613164e+06     1.357512e+06     1.162775e+06
#
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df3 = df2.transpose()
df3
# Out:
# Continent                Asia  South America        Africa        Europe  \
# 2022 Population  9.632739e+07   3.120119e+07  2.545588e+07  1.505537e+07
# 2020 Population  9.495513e+07   3.082357e+07  2.387144e+07  1.491584e+07
# 2015 Population  8.916500e+07   2.950960e+07  2.141970e+07  1.502745e+07
# 2010 Population  8.908777e+07   2.678940e+07  1.889820e+07  1.471228e+07
# 2000 Population  8.058084e+07   2.501589e+07  1.459837e+07  1.481769e+07
# 1990 Population  4.864000e+07   2.122474e+07  1.137696e+07  1.478520e+07
# 1980 Population  4.027833e+07   1.727064e+07  8.586032e+06  1.420000e+07
# 1970 Population  4.383988e+07   1.378194e+07  6.567175e+06  1.311848e+07
#
# Continent        North America       Oceania
# 2022 Population   1.500740e+07  2.046386e+06
# 2020 Population   1.485591e+07  1.910149e+06
# 2015 Population   1.425960e+07  1.756664e+06
# 2010 Population   1.356802e+07  1.613164e+06
# 2000 Population   1.215174e+07  1.357512e+06
# ...

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
# filter data that contains oceania
df[df['Continent'].str.contains('Oceania')]
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# ...

# %%
df.select_dtypes(include='number')
# Out:
#      Rank  2022 Population  2020 Population  2015 Population  2010 Population  \
# 0      36       41128771.0       38972230.0       33753499.0       28189672.0
# 1     138        2842321.0        2866849.0        2882481.0        2913399.0
# 2      34       44903225.0       43451666.0       39543154.0       35856344.0
# 3     213          44273.0          46189.0          51368.0          54849.0
# 4     203          79824.0          77700.0          71746.0          71519.0
# ..    ...              ...              ...              ...              ...
# 229   226          11572.0          11655.0          12182.0          13142.0
# 230   172         575986.0         556048.0         491824.0         413296.0
# 231    46       33696614.0       32284046.0       28516545.0       24743946.0
# 232    63       20017675.0       18927715.0              NaN       13792086.0
# 233    74       16320537.0       15669666.0       14154937.0       12839771.0
#
# ...

# %%
df.select_dtypes(include='object')
# Out:
#     CCA3            Country           Capital Continent
# 0    AFG        Afghanistan             Kabul      Asia
# 1    ALB            Albania            Tirana    Europe
# 2    DZA            Algeria           Algiers    Africa
# 3    ASM     American Samoa         Pago Pago   Oceania
# 4    AND            Andorra  Andorra la Vella    Europe
# ..   ...                ...               ...       ...
# 229  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230  ESH     Western Sahara          El Aaiún    Africa
# 231  YEM              Yemen             Sanaa      Asia
# 232  ZMB             Zambia            Lusaka    Africa
# 233  ZWE           Zimbabwe            Harare    Africa
#
# [234 rows x 4 columns]

# %%
df.select_dtypes(include='float')
# Out:
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# 2         44903225.0       43451666.0       39543154.0       35856344.0
# 3            44273.0          46189.0          51368.0          54849.0
# 4            79824.0          77700.0          71746.0          71519.0
# ..               ...              ...              ...              ...
# 229          11572.0          11655.0          12182.0          13142.0
# 230         575986.0         556048.0         491824.0         413296.0
# 231       33696614.0       32284046.0       28516545.0       24743946.0
# 232       20017675.0       18927715.0              NaN       13792086.0
# 233       16320537.0       15669666.0       14154937.0       12839771.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
import pandas as pd

# Show all columns
pd.set_option('display.max_columns', None)

# Show all rows
pd.set_option('display.max_rows', None)

# Optional: Don't truncate column width
pd.set_option('display.max_colwidth', None)

# Optional: Expand display to full width of the notebook or terminal
pd.set_option('display.width', None)

# Now display your DataFrame
print(df)  # or simply df if you're in a notebook environment
# Out:
#      Rank CCA3                           Country              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda         Saint John’s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
#for view full columns
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
df
# Out:
#      Rank CCA3                           Country              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda         Saint John’s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...
